# %% [markdown]
# **Aanmaken directories**

# %%
# !mkdir convImg
# !mkdir minImg
# !mkdir maxImg
# !mkdir inputImg

# %% [markdown]
# **fetch library std_image**

# %%
# !wget https://raw.githubusercontent.com/nothings/stb/master/stb_image.h
# !wget https://raw.githubusercontent.com/nothings/stb/master/stb_image_write.h
# Out:
# --2023-01-07 00:36:08--  https://raw.githubusercontent.com/nothings/stb/master/stb_image.h
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279339 (273K) [text/plain]
# Saving to: ‘stb_image.h’
#
# stb_image.h         100%[===================>] 272.79K  --.-KB/s    in 0.01s
#
# 2023-01-07 00:36:08 (22.8 MB/s) - ‘stb_image.h’ saved [279339/279339]
#
# --2023-01-07 00:36:08--  https://raw.githubusercontent.com/nothings/stb/master/stb_image_write.h
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71221 (70K) [text/plain]
# Saving to: ‘stb_image_write.h’
#
# stb_image_write.h   100%[===================>]  69.55K  --.-KB/s    in 0.003s
#
# 2023-01-07 00:36:08 (19.4 MB/s) - ‘stb_image_write.h’ saved [71221/71221]

# %% [markdown]
# **download input images**

# %%
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto1.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto2.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto3.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto4.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto5.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto6.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto7.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto8.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto9.png
# !wget -P /content/inputImg/ https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto0.png
# Out:
# --2023-01-07 00:36:12--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35855 (35K) [image/png]
# Saving to: ‘/content/inputImg/foto1.png’
#
# foto1.png           100%[===================>]  35.01K  --.-KB/s    in 0.001s
#
# 2023-01-07 00:36:13 (51.4 MB/s) - ‘/content/inputImg/foto1.png’ saved [35855/35855]
#
# --2023-01-07 00:36:13--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122081 (119K) [image/png]
# Saving to: ‘/content/inputImg/foto2.png’
#
# foto2.png           100%[===================>] 119.22K  --.-KB/s    in 0.007s
#
# 2023-01-07 00:36:13 (15.9 MB/s) - ‘/content/inputImg/foto2.png’ saved [122081/122081]
#
# --2023-01-07 00:36:13--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70206 (69K) [image/png]
# Saving to: ‘/content/inputImg/foto3.png’
#
# foto3.png           100%[===================>]  68.56K  --.-KB/s    in 0.004s
#
# 2023-01-07 00:36:13 (18.0 MB/s) - ‘/content/inputImg/foto3.png’ saved [70206/70206]
#
# --2023-01-07 00:36:13--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto4.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 111288 (109K) [image/png]
# Saving to: ‘/content/inputImg/foto4.png’
#
# foto4.png           100%[===================>] 108.68K  --.-KB/s    in 0.007s
#
# 2023-01-07 00:36:13 (14.8 MB/s) - ‘/content/inputImg/foto4.png’ saved [111288/111288]
#
# --2023-01-07 00:36:14--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto5.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66512 (65K) [image/png]
# Saving to: ‘/content/inputImg/foto5.png’
#
# foto5.png           100%[===================>]  64.95K  --.-KB/s    in 0.003s
#
# 2023-01-07 00:36:14 (18.6 MB/s) - ‘/content/inputImg/foto5.png’ saved [66512/66512]
#
# --2023-01-07 00:36:14--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto6.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141875 (139K) [image/png]
# Saving to: ‘/content/inputImg/foto6.png’
#
# foto6.png           100%[===================>] 138.55K  --.-KB/s    in 0.008s
#
# 2023-01-07 00:36:14 (18.0 MB/s) - ‘/content/inputImg/foto6.png’ saved [141875/141875]
#
# --2023-01-07 00:36:14--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto7.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99817 (97K) [image/png]
# Saving to: ‘/content/inputImg/foto7.png’
#
# foto7.png           100%[===================>]  97.48K  --.-KB/s    in 0.005s
#
# 2023-01-07 00:36:14 (19.9 MB/s) - ‘/content/inputImg/foto7.png’ saved [99817/99817]
#
# --2023-01-07 00:36:14--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto8.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104866 (102K) [image/png]
# Saving to: ‘/content/inputImg/foto8.png’
#
# foto8.png           100%[===================>] 102.41K  --.-KB/s    in 0.007s
#
# 2023-01-07 00:36:15 (15.3 MB/s) - ‘/content/inputImg/foto8.png’ saved [104866/104866]
#
# --2023-01-07 00:36:15--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto9.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90003 (88K) [image/png]
# Saving to: ‘/content/inputImg/foto9.png’
#
# foto9.png           100%[===================>]  87.89K  --.-KB/s    in 0.004s
#
# 2023-01-07 00:36:15 (19.6 MB/s) - ‘/content/inputImg/foto9.png’ saved [90003/90003]
#
# --2023-01-07 00:36:15--  https://raw.githubusercontent.com/JelleClaes2/picturesHAC/main/foto0.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 121028 (118K) [image/png]
# Saving to: ‘/content/inputImg/foto0.png’
#
# foto0.png           100%[===================>] 118.19K  --.-KB/s    in 0.007s
#
# 2023-01-07 00:36:16 (16.2 MB/s) - ‘/content/inputImg/foto0.png’ saved [121028/121028]

# %%
# !git clone https://github.com/nothings/stb.git
# Out:
# Cloning into 'stb'...
# remote: Enumerating objects: 7851, done.
# remote: Total 7851 (delta 0), reused 0 (delta 0), pack-reused 7851
# Receiving objects: 100% (7851/7851), 5.34 MiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (5213/5213), done.

# %%
# %%writefile HAC_eindopdracht.cu
# #include <stdio.h>
# #include <stdlib.h>
# #include "cuda.h"
# #include "cuda_runtime.h"
# #define STB_IMAGE_IMPLEMENTATION
# #define STB_IMAGE_WRITE_IMPLEMENTATION
# #include "stb_image.h"
# #include "stb_image_write.h"
#
# #define MULTIPLIER 4
# #define DEBUG_PRINT 0
# #define INFO_PRINT 0
#
# struct Pixel
# {
# 	unsigned char r, g, b, a;
# };
#
# // *********************
# // **** MIN POOLING ****
# // *********************
# __global__ void minPoolingGpu(unsigned char* imageRGBA, unsigned char* output, size_t stride, int width, int height)
# {
# 	int index = (blockDim.x * blockIdx.x + threadIdx.x);
# 	for (int x = 0; x < (height / 2); x++) // itterate height
# 	{
# 		for (int y = index; y < (width / 2); y += stride) // itterate width
# 		{
# 			// read pixel values
# 			Pixel* pix1 = (Pixel *) &imageRGBA[(y * 2 * 4) + (0 * 4) + (width * 0 * 4) + (x * 2 * width * 4)];
# 			Pixel* pix2 = (Pixel *) &imageRGBA[(y * 2 * 4) + (1 * 4) + (width * 0 * 4) + (x * 2 * width * 4)];
#
# 			Pixel* pix3 = (Pixel *) &imageRGBA[(y * 2 * 4) + (0 * 4) + (width * 1 * 4) + (x * 2 * width * 4)];
# 			Pixel* pix4 = (Pixel *) &imageRGBA[(y * 2 * 4) + (1 * 4) + (width * 1 * 4) + (x * 2 * width * 4)];
#
# 			// output pixel
# 			Pixel* ptrOutputPix = (Pixel *) &output[(y * 4) + (x * (width / 2) * 4)];
# 			// store value for output
# 			int tempPix;
#             // RED channel
#             tempPix = min(pix1->r, pix2->r);
#             tempPix = min(tempPix, pix3->r);
#             tempPix = min(tempPix, pix4->r);
#             ptrOutputPix->r = tempPix;
#             // GREEN channel
#             tempPix = min(pix1->g, pix2->g);
#             tempPix = min(tempPix, pix3->g);
#             tempPix = min(tempPix, pix4->g);
#             ptrOutputPix->g = tempPix;
#             // BLUE channel
#             tempPix = min(pix1->b, pix2->b);
#             tempPix = min(tempPix, pix3->b);
#             tempPix = min(tempPix, pix4->b);
#             if (DEBUG_PRINT)
#                 printf("Min (BLUE): %i\r\n", tempPix);
#             ptrOutputPix->b = tempPix;
#             // ALPHA channel (transparantie)
#             ptrOutputPix->a = 255;
# 		}
# 	}
# }
#
# // *********************
# // **** MAX POOLING ****
# // *********************
# __global__ void maxPoolingGpu(unsigned char* imageRGBA, unsigned char* output, size_t stride, int width, int height)
# {
# 	int index = (blockDim.x * blockIdx.x + threadIdx.x);
# 	for (int x = 0; x < (height / 2); x++) // itterate height
# 	{
# 		for (int y = index; y < (width / 2); y += stride) // itterate width
# 		{
# 			// read pixel values
# 			Pixel* pix1 = (Pixel *) &imageRGBA[(y * 2 * 4) + (0 * 4) + (width * 0 * 4) + (x * 2 * width * 4)];
# 			Pixel* pix2 = (Pixel *) &imageRGBA[(y * 2 * 4) + (1 * 4) + (width * 0 * 4) + (x * 2 * width * 4)];
#
# 			Pixel* pix3 = (Pixel *) &imageRGBA[(y * 2 * 4) + (0 * 4) + (width * 1 * 4) + (x * 2 * width * 4)];
# 			Pixel* pix4 = (Pixel *) &imageRGBA[(y * 2 * 4) + (1 * 4) + (width * 1 * 4) + (x * 2 * width * 4)];
#
# 			// output pixel
# 			Pixel* ptrOutputPix = (Pixel *) &output[(y * 4) + (x * (width / 2) * 4)];
# 			// store value for output
# 			int tempPix;
#             // RED channel
#             tempPix = max(pix1->r, pix2->r);
#             tempPix = max(tempPix, pix3->r);
#             tempPix = max(tempPix, pix4->r);
#             if (DEBUG_PRINT)
#                 printf("Max (RED): %i\r\n", tempPix);
#             ptrOutputPix->r = tempPix;
#             // GREEN channel
#             tempPix = max(pix1->g, pix2->g);
#             tempPix = max(tempPix, pix3->g);
#             tempPix = max(tempPix, pix4->g);
#             if (DEBUG_PRINT)
#                 printf("Max (GREEN): %i\r\n", tempPix);
#             ptrOutputPix->g = tempPix;
#             // BLUE channel
#             tempPix = max(pix1->b, pix2->b);
#             tempPix = max(tempPix, pix3->b);
#             tempPix = max(tempPix, pix4->b);
#             if (DEBUG_PRINT)
#                 printf("Max (BLUE): %i\r\n", tempPix);
#             ptrOutputPix->b = tempPix;
#             // ALPHA channel (transparantie)
#             ptrOutputPix->a = 255;
#
# 		}
# 	}
# }
#
# // *********************
# // ***** GRAYSCALE *****
# // *********************
# __global__ void ConvertImageToGrayGpu(unsigned char* imageRGBA, size_t pixels, size_t stride, int width)
# {
# 	int index = (blockDim.x * blockIdx.x + threadIdx.x) * 4;
# 	for (int i = index; i < pixels; i += stride)
#     {
# 		Pixel* ptrPixel = (Pixel*)&imageRGBA[i];
# 		unsigned char pixelValue = (unsigned char)(ptrPixel->r * 0.2126f + ptrPixel->g * 0.7152f + ptrPixel->b * 0.0722f);
# 		ptrPixel->r = pixelValue; // Store the data directly into the input image
# 		ptrPixel->g = pixelValue;
# 		ptrPixel->b = pixelValue;
# 		ptrPixel->a = 255;
#     }
# }
#
# // *********************
# // **** CONVOLUTION ****
# // *********************
# __global__ void imageConvolutionGpu(unsigned char* inputImage, unsigned char* outputImage, size_t stride, int width, int height, int16_t * kernel)
# {
# 	int index = (blockDim.x * blockIdx.x + threadIdx.x);
# 	for (int x = 0; x < (height - 2); x++) // itterate height
# 	{
# 		for (int y = index; y < (width - 2); y += stride) // itterate width
# 		{
# 			// read matrix pixels values
# 			Pixel* pix1 = (Pixel *) &inputImage[(y * 4) + (0 * 4) + (width * 0 * 4) + (x * width * 4)];
# 			Pixel* pix2 = (Pixel *) &inputImage[(y * 4) + (1 * 4) + (width * 0 * 4) + (x * width * 4)];
# 			Pixel* pix3 = (Pixel *) &inputImage[(y * 4) + (2 * 4) + (width * 0 * 4) + (x * width * 4)];
#
# 			Pixel* pix4 = (Pixel *) &inputImage[(y * 4) + (0 * 4) + (width * 1 * 4) + (x * width * 4)];
# 			Pixel* pix5 = (Pixel *) &inputImage[(y * 4) + (1 * 4) + (width * 1 * 4) + (x * width * 4)];
# 			Pixel* pix6 = (Pixel *) &inputImage[(y * 4) + (2 * 4) + (width * 1 * 4) + (x * width * 4)];
#
# 			Pixel* pix7 = (Pixel *) &inputImage[(y * 4) + (0 * 4) + (width * 2 * 4) + (x * width * 4)];
# 			Pixel* pix8 = (Pixel *) &inputImage[(y * 4) + (1 * 4) + (width * 2 * 4) + (x * width * 4)];
# 			Pixel* pix9 = (Pixel *) &inputImage[(y * 4) + (2 * 4) + (width * 2 * 4) + (x * width * 4)];
#
# 			// output pixel
# 			Pixel* ptrOutputPix = (Pixel *) &outputImage[(y * 4) + (x * (width - 2) * 4)];
# 			// store value for output
# 			int ConValue;
#
# 			// RED channel
# 			ConValue = pix1->r * kernel[0] + pix2->r * kernel[1] + pix3->r * kernel[2] + pix4->r * kernel[3] + pix5->r * kernel[4] + pix6->r * kernel[5] + pix7->r * kernel[6] + pix8->r * kernel[7] + pix9->r * kernel[8];
# 			if (ConValue < 0){
#                 ptrOutputPix->r = 0;
#             }
# 			else if (ConValue > 255){
#                 ptrOutputPix->r = 255;
#             }
# 			else
# 				ptrOutputPix->r = ConValue;
# 			// GREEN channel
# 			ConValue = pix1->g * kernel[0] + pix2->g * kernel[1] + pix3->g * kernel[2] + pix4->g * kernel[3] + pix5->g * kernel[4] + pix6->g * kernel[5] + pix7->g * kernel[6] + pix8->g * kernel[7] + pix9->g * kernel[8];
# 			if (ConValue < 0){
#                 ptrOutputPix->g = 0;
#             }
# 			else if (ConValue > 255){
#                 ptrOutputPix->g = 255;
#             }
# 			else
# 				ptrOutputPix->g = ConValue;
# 			// BLUE channel
# 			ConValue = pix1->b * kernel[0] + pix2->b * kernel[1] + pix3->b * kernel[2] + pix4->b * kernel[3] + pix5->b * kernel[4] + pix6->b * kernel[5] + pix7->b * kernel[6] + pix8->b * kernel[7] + pix9->b * kernel[8];
# 			if (ConValue < 0){
#                 ptrOutputPix->b = 0;
#             }
# 			else if (ConValue > 255){
#                 ptrOutputPix->b = 255;
#             }
# 			else
# 				ptrOutputPix->b = ConValue;
# 			// ALPHA channel
# 			ptrOutputPix->a = 255;
# 		}
# 	}
# }
#
# // **********************
# // **** MAIN PROGRAM ****
# // **********************
# int main(int argc, char** argv)
# {
#     // 3x3 KERNEL matrix
# 	int16_t kernel[9] =
# 	{
# 		1, 0, -1,
# 		1, 0, -1,
# 		1, 0, -1
# 	};
#
#     // preproces
# 	char fileName[32];
# 	unsigned char *inputArr[10]; // input image data
# 	unsigned char *outputArr[3][10]; // output image data
#     int componentCount;
# 	int width[10];
# 	int height[10];
#
#     cudaEvent_t start, stop;
# 	cudaEventCreate(&start);
# 	cudaEventCreate(&stop);
# 	float GpuTimer;
#
#     printf("********************************\r\n");
#     printf("** CONVOLUTION & POOLING TOOL **\r\n");
#     printf("********************************\r\n\r\n");
#
# 	printf("reading images...\r\n");
#
# 	for (int i = 0; i < 10; i++) // Load all 10 images
# 	{
# 		memset(fileName, '\0', 32);
# 		char folder_path_input[100] = "/content/inputImg/";
# 		sprintf(fileName, "%sfoto%i.png", folder_path_input, i); // Create the file name, these are saves as: mage_in_x.png where x is a number from 0 to 9
#
# 		printf("loading : %s\r\n", fileName);
#
# 		inputArr[i] = stbi_load(fileName, &width[i], &height[i], &componentCount, 4);
# 		if (!inputArr[i])
#             printf("failed to open image %i\r\n", i+(i*(-2)));
#
#         // min pool
# 		outputArr[0][i] = (unsigned char *) malloc((width[i] / 2) * (height[i] / 2) * 4);
#         // max pool
# 		outputArr[1][i] = (unsigned char *) malloc((width[i] / 2) * (height[i] / 2) * 4);
#         // convolution
# 		outputArr[2][i] = (unsigned char *) malloc((width[i] - 2) * (height[i] - 2) * 4);
# 	}
#
#     // GPU
# 	int device;
# 	cudaGetDevice(&device);
# 	cudaDeviceProp properties;
# 	cudaGetDeviceProperties(&properties, device);
#
# 	size_t RGBA[10];
# 	size_t threads_per_block[10];
# 	size_t number_of_blocks[10];
# 	size_t stride[10];
#
# 	int16_t *ptrKernel = nullptr;
# 	unsigned char *ptrInputImg[10];
# 	unsigned char *ptrOutputImg[3][10]; // min, avr, max and con
#
# 	for (int i = 0; i < 10; i++)
# 	{
# 		RGBA[i] = width[i] * height[i] * 4;
# 		threads_per_block[i] = min(properties.maxThreadsPerMultiProcessor, width[i]);
# 		number_of_blocks[i] = (RGBA[i] + threads_per_block[i] - 1) / threads_per_block[i];
# 		stride[i] = threads_per_block[i] * number_of_blocks[i];
# 	}
#
# 	cudaEventRecord(start);
#
# 	// Kernel alloc
# 	cudaMalloc(&ptrKernel, 9 * sizeof(int16_t));
# 	cudaMemcpy(ptrKernel, kernel, 9 * sizeof(int16_t), cudaMemcpyHostToDevice);
#
#     // Host 2 Device
# 	for (int i = 0; i < 10; i++)
# 	{
# 		ptrInputImg[i] = nullptr;
# 		ptrOutputImg[0][i] = nullptr;
# 		ptrOutputImg[1][i] = nullptr;
# 		ptrOutputImg[2][i] = nullptr;
#
# 		cudaMalloc(&ptrInputImg[i], width[i] * height[i] * 4);
# 		cudaMalloc(&ptrOutputImg[0][i], (width[i] / 2) * (height[i] / 2) * 4);
# 		cudaMalloc(&ptrOutputImg[1][i], (width[i] / 2) * (height[i] / 2) * 4);
# 		cudaMalloc(&ptrOutputImg[2][i], (width[i] - 2) * (height[i] - 2) * 4);
#
# 		cudaMemcpy(ptrInputImg[i], inputArr[i], width[i] * height[i] * 4, cudaMemcpyHostToDevice);
# 		cudaMemcpy(ptrOutputImg[0][i], outputArr[0][i], (width[i] / 2) * (height[i] / 2) * 4, cudaMemcpyHostToDevice);
# 		cudaMemcpy(ptrOutputImg[1][i], outputArr[1][i], (width[i] / 2) * (height[i] / 2) * 4, cudaMemcpyHostToDevice);
# 		cudaMemcpy(ptrOutputImg[2][i], outputArr[2][i], (width[i] - 2) * (height[i] - 2) * 4, cudaMemcpyHostToDevice);
# 	}
# 	cudaDeviceSynchronize();
#
# 	// min pool
# 	for (int i = 0; i < 10; i++)
# 	{
# 		cudaStream_t stream;
# 		cudaStreamCreate(&stream);
# 		minPoolingGpu<<<number_of_blocks[i], threads_per_block[i], 0, stream>>>(ptrInputImg[i], ptrOutputImg[0][i], stride[i], width[i], height[i]);
# 		cudaStreamDestroy(stream);
# 	}
#
# 	// max pool
# 	for (int i = 0; i < 10; i++)
# 	{
# 		cudaStream_t stream;
# 		cudaStreamCreate(&stream);
# 		maxPoolingGpu<<<number_of_blocks[i], threads_per_block[i], 0, stream>>>(ptrInputImg[i], ptrOutputImg[1][i], stride[i], width[i], height[i]);
# 		cudaStreamDestroy(stream);
# 	}
# 	cudaDeviceSynchronize();
#
# 	// Preprocess Convovlution
# 	for (int i = 0; i < 10; i++)
# 	{
# 		cudaStream_t stream;
# 		cudaStreamCreate(&stream);
# 		ConvertImageToGrayGpu<<<number_of_blocks[i], threads_per_block[i], 0, stream>>>(ptrInputImg[i], RGBA[i], stride[i], width[i]);
# 		cudaStreamDestroy(stream);
# 	}
# 	cudaDeviceSynchronize();
#
# 	// Convolution
# 	for (int i = 0; i < 10; i++)
# 	{
# 		cudaStream_t stream;
# 		cudaStreamCreate(&stream);
# 		imageConvolutionGpu<<<number_of_blocks[i], threads_per_block[i], 0, stream>>>(ptrInputImg[i], ptrOutputImg[2][i], stride[i], width[i], height[i], ptrKernel);
# 		cudaStreamDestroy(stream);
# 	}
# 	cudaDeviceSynchronize();
#
# 	// Device 2 Host
# 	for (int i = 0; i < 10; i++)
# 	{
# 		cudaMemcpy(outputArr[0][i], ptrOutputImg[0][i], (width[i] / 2) * (height[i] / 2) * 4, cudaMemcpyDeviceToHost);
# 		cudaMemcpy(outputArr[1][i], ptrOutputImg[1][i], (width[i] / 2) * (height[i] / 2) * 4, cudaMemcpyDeviceToHost);
# 		cudaMemcpy(outputArr[2][i], ptrOutputImg[2][i], (width[i] - 2) * (height[i] - 2) * 4, cudaMemcpyDeviceToHost);
# 	}
# 	cudaDeviceSynchronize();
#
# 	cudaEventRecord(stop);
# 	cudaEventSynchronize(stop);
# 	GpuTimer = 0;
# 	cudaEventElapsedTime(&GpuTimer, start, stop);
#
# 	printf("writing files...\r\n");
# 	for (int i = 0; i < 10; i++)
# 	{
# 		memset(fileName, '\0', 16);
# 		sprintf(fileName, "/content/minImg/min_%i.png", i);
# 		if (DEBUG_PRINT)
# 			printf("Image file name: %s", fileName);
# 		stbi_write_png(fileName, width[i] / 2, height[i] / 2, 4, outputArr[0][i], 4 * (width[i] / 2));
#
# 		memset(fileName, '\0', 16);
# 		sprintf(fileName, "/content/maxImg/max_%i.png", i);
# 		if (DEBUG_PRINT)
# 			printf("Image file name: %s", fileName);
# 		stbi_write_png(fileName, width[i] / 2, height[i] / 2, 4, outputArr[1][i], 4 * (width[i] / 2));
#
# 		memset(fileName, '\0', 16);
# 		sprintf(fileName, "/content/convImg/con_%i.png", i);
# 		if (DEBUG_PRINT)
# 			printf("Image file name: %s", fileName);
# 		stbi_write_png(fileName, width[i] - 2, height[i] - 2, 4, outputArr[2][i], 4 * (width[i] - 2));
# 	}
#
#     // free memory
# 	cudaFree(ptrKernel);
# 	for (int i = 0; i < 10; i++)
# 	{
# 		cudaFree(ptrInputImg[i]);
# 		cudaFree(ptrOutputImg[0][i]);
# 		cudaFree(ptrOutputImg[1][i]);
# 		cudaFree(ptrOutputImg[2][i]);
# 		stbi_image_free(inputArr[i]);
# 		free(outputArr[0][i]);
# 		free(outputArr[1][i]);
# 		free(outputArr[2][i]);
# 	}
#
# 	printf("finished process...\r\n");
#
# 	printf("Process time on GPU : %3.9f ms\r\n", GpuTimer);
#
# 	return 0;
# }
# Out:
# Overwriting HAC_eindopdracht.cu

# %%
# !nvcc HAC_eindopdracht.cu -o run
# Out:
# stb_image.h(4207): warning: variable "old_limit" was set but never used
#
# stb_image.h(5121): warning: variable "idata_limit_old" was set but never used
#
# stb_image.h(6894): warning: variable "out_size" was set but never used
#
# stb_image.h(6895): warning: variable "delays_size" was set but never used

# %%
# !./run
# Out:
# ********************************
# ** CONVOLUTION & POOLING TOOL **
# ********************************
#
# reading images...
# loading : /content/inputImg/foto0.png
# loading : /content/inputImg/foto1.png
# loading : /content/inputImg/foto2.png
# loading : /content/inputImg/foto3.png
# loading : /content/inputImg/foto4.png
# loading : /content/inputImg/foto5.png
# loading : /content/inputImg/foto6.png
# loading : /content/inputImg/foto7.png
# loading : /content/inputImg/foto8.png
# loading : /content/inputImg/foto9.png
# writing files...
# finished process...
# Process time on GPU : 11.367168427 ms

# %%
# !zip -r /content/HacFinal.zip /content/
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 25%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2023.01.05/ (stored 0%)
#   adding: content/.config/logs/2023.01.05/14.33.30.524625.log (deflated 54%)
#   adding: content/.config/logs/2023.01.05/14.33.16.757082.log (deflated 86%)
#   adding: content/.config/logs/2023.01.05/14.32.48.311993.log (deflated 53%)
#   adding: content/.config/logs/2023.01.05/14.32.18.784307.log (deflated 91%)
#   adding: content/.config/logs/2023.01.05/14.34.00.192801.log (deflated 54%)
#   adding: content/.config/logs/2023.01.05/14.34.01.063009.log (deflated 53%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/minImg/ (stored 0%)
#   adding: content/minImg/min_0.png (deflated 2%)
#   adding: content/minImg/min_8.png (deflated 2%)
#   adding: content/minImg/min_4.png (deflated 2%)
#   adding: content/minImg/min_7.png (deflated 2%)
#   adding: content/minImg/min_2.png (deflated 2%)
#   adding: content/minImg/min_5.png (deflated 2%)
#   adding: content/minImg/min_6.png (deflated 3%)
#   adding: content/minImg/min_1.png (deflated 3%)
#   adding: content/minImg/min_3.png (deflated 2%)
#   adding: content/minImg/min_9.png (deflated 2%)
#   adding: content/maxImg/ (stored 0%)
#   adding: content/maxImg/max_5.png (deflated 2%)
#   adding: content/maxImg/max_9.png (deflated 2%)
#   adding: content/maxImg/max_1.png (deflated 3%)
#   adding: content/maxImg/max_0.png (deflated 2%)
#   adding: content/maxImg/max_8.png (deflated 2%)
#   adding: content/maxImg/max_3.png (deflated 2%)
#   adding: content/maxImg/max_7.png (deflated 2%)
#   adding: content/maxImg/max_6.png (deflated 3%)
#   adding: content/maxImg/max_2.png (deflated 2%)
#   adding: content/maxImg/max_4.png (deflated 2%)
#   adding: content/run (deflated 69%)
#   adding: content/HAC_eindopdracht.cu (deflated 80%)
#   adding: content/inputImg/ (stored 0%)
#   adding: content/inputImg/foto5.png (deflated 1%)
#   adding: content/inputImg/foto7.png (deflated 0%)
#   adding: content/inputImg/foto1.png (deflated 1%)
#   adding: content/inputImg/foto9.png (deflated 0%)
#   adding: content/inputImg/foto8.png (deflated 0%)
#   adding: content/inputImg/foto3.png (deflated 0%)
#   adding: content/inputImg/foto6.png (deflated 0%)
#   adding: content/inputImg/foto0.png (deflated 0%)
#   adding: content/inputImg/foto4.png (deflated 0%)
#   adding: content/inputImg/foto2.png (deflated 0%)
#   adding: content/stb/ (stored 0%)
#   adding: content/stb/stb_hexwave.h (deflated 69%)
#   adding: content/stb/docs/ (stored 0%)
#   adding: content/stb/docs/stb_howto.txt (deflated 54%)
#   adding: content/stb/docs/stb_voxel_render_interview.md (deflated 54%)
#   adding: content/stb/docs/other_libs.md (deflated 2%)
#   adding: content/stb/docs/why_public_domain.md (deflated 56%)
#   adding: content/stb/stb_voxel_render.h (deflated 77%)
#   adding: content/stb/stb_include.h (deflated 71%)
#   adding: content/stb/.travis.yml (deflated 11%)
#   adding: content/stb/stb_dxt.h (deflated 68%)
#   adding: content/stb/stb_textedit.h (deflated 77%)
#   adding: content/stb/stb_herringbone_wang_tile.h (deflated 78%)
#   adding: content/stb/tools/ (stored 0%)
#   adding: content/stb/tools/trailing_whitespace.c (deflated 53%)
#   adding: content/stb/tools/mr.bat (stored 0%)
#   adding: content/stb/tools/README.header.md (deflated 49%)
#   adding: content/stb/tools/make_readme.c (deflated 62%)
#   adding: content/stb/tools/README.footer.md (deflated 54%)
#   adding: content/stb/tools/make_readme.dsp (deflated 76%)
#   adding: content/stb/tools/README.list (deflated 58%)
#   adding: content/stb/tools/unicode.c (deflated 72%)
#   adding: content/stb/tools/unicode/ (stored 0%)
#   adding: content/stb/tools/unicode/unicode.dsp (deflated 76%)
#   adding: content/stb/tools/build_matrix.c (deflated 72%)
#   adding: content/stb/tools/easy_font_maker.c (deflated 71%)
#   adding: content/stb/stb_ds.h (deflated 75%)
#   adding: content/stb/stb_sprintf.h (deflated 74%)
#   adding: content/stb/stb_tilemap_editor.h (deflated 77%)
#   adding: content/stb/deprecated/ (stored 0%)
#   adding: content/stb/deprecated/stretch_test.c (deflated 51%)
#   adding: content/stb/deprecated/rrsprintf.h (deflated 68%)
#   adding: content/stb/deprecated/stretchy_buffer.h (deflated 62%)
#   adding: content/stb/deprecated/stb.h (deflated 77%)
#   adding: content/stb/deprecated/stb_image.c (deflated 73%)
#   adding: content/stb/deprecated/stretchy_buffer.txt (deflated 60%)
#   adding: content/stb/.github/ (stored 0%)
#   adding: content/stb/.github/CONTRIBUTING.md (deflated 45%)
#   adding: content/stb/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/stb/.github/ISSUE_TEMPLATE/bug_report.md (deflated 42%)
#   adding: content/stb/.github/ISSUE_TEMPLATE/feature_request.md (deflated 49%)
#   adding: content/stb/.github/ISSUE_TEMPLATE/config.yml (deflated 27%)
#   adding: content/stb/.github/PULL_REQUEST_TEMPLATE.md (deflated 40%)
#   adding: content/stb/.github/workflows/ (stored 0%)
#   adding: content/stb/.github/workflows/ci-fuzz.yml (deflated 58%)
#   adding: content/stb/stb_truetype.h (deflated 75%)
#   adding: content/stb/stb_easy_font.h (deflated 63%)
#   adding: content/stb/stb_c_lexer.h (deflated 74%)
#   adding: content/stb/stb_leakcheck.h (deflated 66%)
#   adding: content/stb/stb_vorbis.c (deflated 73%)
#   adding: content/stb/stb_divide.h (deflated 69%)
#   adding: content/stb/README.md (deflated 56%)
#   adding: content/stb/stb_rect_pack.h (deflated 67%)
#   adding: content/stb/stb_image_resize.h (deflated 81%)
#   adding: content/stb/tests/ (stored 0%)
#   adding: content/stb/tests/herringbone.dsp (deflated 76%)
#   adding: content/stb/tests/stblib_test_companion.c (deflated 56%)
#   adding: content/stb/tests/image_write_test.c (deflated 61%)
#   adding: content/stb/tests/test_voxel.c (stored 0%)
#   adding: content/stb/tests/test_cpp_compilation.cpp (deflated 71%)
#   adding: content/stb/tests/test_c_lexer.c (deflated 64%)
#   adding: content/stb/tests/stblib.dsp (deflated 76%)
#   adding: content/stb/tests/resample_test_c.c (deflated 20%)
#   adding: content/stb/tests/test_truetype.c (deflated 64%)
#   adding: content/stb/tests/test_vorbis.c (deflated 38%)
#   adding: content/stb/tests/grid_reachability.c (deflated 75%)
#   adding: content/stb/tests/test_image.c (deflated 24%)
#   adding: content/stb/tests/truetype_test_win32.c (deflated 59%)
#   adding: content/stb/tests/image_test.c (deflated 73%)
#   adding: content/stb/tests/textedit_sample.c (deflated 69%)
#   adding: content/stb/tests/herringbone_generator.c (deflated 69%)
#   adding: content/stb/tests/caveview/ (stored 0%)
#   adding: content/stb/tests/caveview/caveview.h (deflated 53%)
#   adding: content/stb/tests/caveview/cave_parse.h (deflated 58%)
#   adding: content/stb/tests/caveview/stb_glprog.h (deflated 76%)
#   adding: content/stb/tests/caveview/cave_render.c (deflated 72%)
#   adding: content/stb/tests/caveview/glext_list.h (deflated 60%)
#   adding: content/stb/tests/caveview/README.md (deflated 53%)
#   adding: content/stb/tests/caveview/cave_parse.c (deflated 73%)
#   adding: content/stb/tests/caveview/stb_gl.h (deflated 75%)
#   adding: content/stb/tests/caveview/cave_mesher.c (deflated 74%)
#   adding: content/stb/tests/caveview/caveview.dsp (deflated 75%)
#   adding: content/stb/tests/caveview/main.c (stored 0%)
#   adding: content/stb/tests/caveview/caveview.dsw (deflated 61%)
#   adding: content/stb/tests/caveview/win32/ (stored 0%)
#   adding: content/stb/tests/caveview/win32/SDL_windows_main.c (deflated 63%)
#   adding: content/stb/tests/caveview/glext.h (deflated 87%)
#   adding: content/stb/tests/caveview/cave_main.c (deflated 69%)
#   adding: content/stb/tests/c_lexer_test.dsp (deflated 76%)
#   adding: content/stb/tests/fuzz_main.c (deflated 56%)
#   adding: content/stb/tests/test_dxt.c (stored 0%)
#   adding: content/stb/tests/stb.dsp (deflated 80%)
#   adding: content/stb/tests/test.sbm (deflated 62%)
#   adding: content/stb/tests/test_sprintf.c (deflated 69%)
#   adding: content/stb/tests/tilemap_editor_integration_example.c (deflated 71%)
#   adding: content/stb/tests/Makefile (deflated 51%)
#   adding: content/stb/tests/stbi_read_fuzzer.c (deflated 39%)
#   adding: content/stb/tests/sdf/ (stored 0%)
#   adding: content/stb/tests/sdf/sdf_test_times_16.png (deflated 21%)
#   adding: content/stb/tests/sdf/sdf_test_times_50.png (deflated 21%)
#   adding: content/stb/tests/sdf/sdf_test_arial_16.png (deflated 18%)
#   adding: content/stb/tests/sdf/sdf_test.c (deflated 61%)
#   adding: content/stb/tests/image_test.dsp (deflated 76%)
#   adding: content/stb/tests/stb_cpp.cpp (deflated 67%)
#   adding: content/stb/tests/stretch_test.dsp (deflated 75%)
#   adding: content/stb/tests/herringbone_map.c (deflated 67%)
#   adding: content/stb/tests/pngsuite/ (stored 0%)
#   adding: content/stb/tests/pngsuite/iphone/ (stored 0%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_basi0g02.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_basi0g01.png (stored 0%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_bgwn6a08.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_z06n2c08.png (deflated 26%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_tbyn3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_bgyn6a16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/iphone/iphone_basi3p02.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary_check/ (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/s34n3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary_check/s35n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/bgwn6a08.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/bgai4a08.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/s40n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/bgan6a08.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/basn0g08.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/z03n2c08.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary_check/tp1n3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/tbbn3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/s02n3p01.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/s32i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary_check/basi2c08.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/basn0g02.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary_check/basi4a08.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/s39n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/bgbn4a08.png (deflated 13%)
#   adding: content/stb/tests/pngsuite/primary_check/basn3p01.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/s04n3p01.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/z09n2c08.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary_check/s06i3p02.png (deflated 11%)
#   adding: content/stb/tests/pngsuite/primary_check/basi0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary_check/s03i3p01.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/s01i3p01.png (deflated 13%)
#   adding: content/stb/tests/pngsuite/primary_check/z00n2c08.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary_check/s07n3p02.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/s40i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/basi6a08.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/tp0n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/tbrn2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/s04i3p01.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/s05i3p02.png (deflated 10%)
#   adding: content/stb/tests/pngsuite/primary_check/basi0g02.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary_check/tbyn3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/basn3p04.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary_check/s08n3p02.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/basi0g08.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/s05n3p02.png (deflated 10%)
#   adding: content/stb/tests/pngsuite/primary_check/basn3p08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary_check/s01n3p01.png (deflated 13%)
#   adding: content/stb/tests/pngsuite/primary_check/tp0n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/basi0g04.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/s38n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/basi3p02.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary_check/s37n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/basi3p04.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/s36n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/s33n3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/s32n3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary_check/tbwn3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/s34i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary_check/basn3p02.png (deflated 6%)
#   adding: content/stb/tests/pngsuite/primary_check/s03n3p01.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/tp0n3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary_check/s35i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/basi3p01.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/s09n3p02.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/tbbn0g04.png (deflated 0%)
#   adding: content/stb/tests/pngsuite/primary_check/s38i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/s33i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/basn6a08.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/s08i3p02.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/basn4a08.png (deflated 11%)
#   adding: content/stb/tests/pngsuite/primary_check/basn0g04.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary_check/basn2c08.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary_check/basi3p08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary_check/basn0g01.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary_check/s07i3p02.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/s09i3p02.png (deflated 8%)
#   adding: content/stb/tests/pngsuite/primary_check/s06n3p02.png (deflated 11%)
#   adding: content/stb/tests/pngsuite/primary_check/s36i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/s39i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/s02i3p01.png (deflated 12%)
#   adding: content/stb/tests/pngsuite/primary_check/s37i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary_check/z06n2c08.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary_check/tm3n3p02.png (deflated 14%)
#   adding: content/stb/tests/pngsuite/primary_check/tbgn3p08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g25n3p04.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/unused/cs8n3p08.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/unused/cdhn2c08.png (deflated 0%)
#   adding: content/stb/tests/pngsuite/unused/g04n0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g03n3p04.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/unused/g10n0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g07n3p04.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/unused/g10n3p04.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/unused/cten0g04.png (deflated 25%)
#   adding: content/stb/tests/pngsuite/unused/g05n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/f01n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/f99n0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ccwn3p08.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/unused/f00n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/f03n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ch2n3p08.png (deflated 38%)
#   adding: content/stb/tests/pngsuite/unused/cdfn2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/pp0n2c16.png (deflated 29%)
#   adding: content/stb/tests/pngsuite/unused/cs3n2c16.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/unused/g25n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g07n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/f01n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/cm9n0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/cthn0g04.png (deflated 42%)
#   adding: content/stb/tests/pngsuite/unused/cdsn2c08.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/unused/f04n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ctfn0g04.png (deflated 21%)
#   adding: content/stb/tests/pngsuite/unused/ps1n0g08.png (deflated 61%)
#   adding: content/stb/tests/pngsuite/unused/g10n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ctzn0g04.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/unused/cm0n0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ctgn0g04.png (deflated 34%)
#   adding: content/stb/tests/pngsuite/unused/f04n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g07n0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ct0n0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/cs8n2c08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/unused/cdun2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g04n3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/unused/f02n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ct1n0g04.png (deflated 13%)
#   adding: content/stb/tests/pngsuite/unused/g05n3p04.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/unused/g03n0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g04n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/cs5n3p08.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/unused/ccwn2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/cs3n3p08.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/unused/pp0n6a08.png (deflated 38%)
#   adding: content/stb/tests/pngsuite/unused/f03n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ps2n2c16.png (deflated 68%)
#   adding: content/stb/tests/pngsuite/unused/ps1n2c16.png (deflated 53%)
#   adding: content/stb/tests/pngsuite/unused/ps2n0g08.png (deflated 75%)
#   adding: content/stb/tests/pngsuite/unused/cm7n0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/f02n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g03n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ch1n3p04.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/unused/f00n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/cs5n2c08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/unused/g05n0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/g25n0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/unused/ctjn0g04.png (deflated 22%)
#   adding: content/stb/tests/pngsuite/corrupt/ (stored 0%)
#   adding: content/stb/tests/pngsuite/corrupt/xd9n2c08.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/corrupt/xcsn0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xs1n0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xhdn0g08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/corrupt/xs4n0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xc1n0g08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/corrupt/xd0n2c08.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xd3n2c08.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/corrupt/xc9n2c08.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/corrupt/xcrn0g04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xs7n0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xdtn0g01.png (deflated 11%)
#   adding: content/stb/tests/pngsuite/corrupt/xs2n0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/corrupt/xlfn0g04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/PngSuite.LICENSE (deflated 20%)
#   adding: content/stb/tests/pngsuite/primary/ (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s34n3p04.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/s35n3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/bgwn6a08.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary/bgai4a08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s40n3p04.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/bgan6a08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/basn0g08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary/z03n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/tp1n3p08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/tbbn3p08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/s02n3p01.png (deflated 10%)
#   adding: content/stb/tests/pngsuite/primary/s32i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basi2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/basn0g02.png (deflated 6%)
#   adding: content/stb/tests/pngsuite/primary/basi4a08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s39n3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/bgbn4a08.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary/basn3p01.png (deflated 6%)
#   adding: content/stb/tests/pngsuite/primary/s04n3p01.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/z09n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s06i3p02.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basi0g01.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s03i3p01.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/s01i3p01.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary/z00n2c08.png (deflated 92%)
#   adding: content/stb/tests/pngsuite/primary/s07n3p02.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/s40i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basi6a08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/tp0n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/tbrn2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s04i3p01.png (deflated 6%)
#   adding: content/stb/tests/pngsuite/primary/s05i3p02.png (deflated 6%)
#   adding: content/stb/tests/pngsuite/primary/basi0g02.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary/tbyn3p08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/basn3p04.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary/s08n3p02.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary/basi0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s05n3p02.png (deflated 6%)
#   adding: content/stb/tests/pngsuite/primary/basn3p08.png (deflated 15%)
#   adding: content/stb/tests/pngsuite/primary/s01n3p01.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary/tp0n0g08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/basi0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s38n3p04.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/basi3p02.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/s37n3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basi3p04.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/s36n3p04.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/s33n3p04.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary/s32n3p04.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/tbwn3p08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/s34i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basn3p02.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/s03n3p01.png (deflated 9%)
#   adding: content/stb/tests/pngsuite/primary/tp0n3p08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/s35i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary/basi3p01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/s09n3p02.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary/tbbn0g04.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/s38i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/s33i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary/basn6a08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/s08i3p02.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basn4a08.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basn0g04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/basn2c08.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary/basi3p08.png (deflated 11%)
#   adding: content/stb/tests/pngsuite/primary/basn0g01.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/s07i3p02.png (deflated 4%)
#   adding: content/stb/tests/pngsuite/primary/s09i3p02.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/s06n3p02.png (deflated 5%)
#   adding: content/stb/tests/pngsuite/primary/s36i3p04.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/primary/s39i3p04.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/primary/s02i3p01.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/primary/s37i3p04.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/primary/z06n2c08.png (stored 0%)
#   adding: content/stb/tests/pngsuite/primary/tm3n3p02.png (deflated 13%)
#   adding: content/stb/tests/pngsuite/primary/tbgn3p08.png (deflated 1%)
#   adding: content/stb/tests/pngsuite/16bit/ (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/bgan6a16.png (deflated 0%)
#   adding: content/stb/tests/pngsuite/16bit/oi1n0g16.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/16bit/oi4n2c16.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/16bit/oi9n2c16.png (deflated 63%)
#   adding: content/stb/tests/pngsuite/16bit/basn0g16.png (deflated 2%)
#   adding: content/stb/tests/pngsuite/16bit/bggn4a16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/basi6a16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/oi1n2c16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/tbbn2c16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/basi4a16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/oi9n0g16.png (deflated 53%)
#   adding: content/stb/tests/pngsuite/16bit/bgai4a16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/oi2n2c16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/tbwn0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/basn4a16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/basn2c16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/oi4n0g16.png (deflated 7%)
#   adding: content/stb/tests/pngsuite/16bit/basi2c16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/tbgn2c16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/basi0g16.png (stored 0%)
#   adding: content/stb/tests/pngsuite/16bit/oi2n0g16.png (deflated 3%)
#   adding: content/stb/tests/pngsuite/16bit/bgyn6a16.png (deflated 0%)
#   adding: content/stb/tests/pngsuite/16bit/basn6a16.png (deflated 0%)
#   adding: content/stb/tests/test_siphash.c (deflated 38%)
#   adding: content/stb/tests/stb_png.dict (deflated 29%)
#   adding: content/stb/tests/resize.dsp (deflated 75%)
#   adding: content/stb/tests/vorbseek/ (stored 0%)
#   adding: content/stb/tests/vorbseek/vorbseek.dsp (deflated 76%)
#   adding: content/stb/tests/vorbseek/vorbseek.c (deflated 64%)
#   adding: content/stb/tests/test_perlin.c (stored 0%)
#   adding: content/stb/tests/herringbone_map.dsp (deflated 76%)
#   adding: content/stb/tests/stb.dsw (deflated 85%)
#   adding: content/stb/tests/stb_c_lexer_fuzzer.cpp (deflated 66%)
#   adding: content/stb/tests/test_easyfont.c (deflated 41%)
#   adding: content/stb/tests/prerelease/ (stored 0%)
#   adding: content/stb/tests/prerelease/stb_lib.h (deflated 78%)
#   adding: content/stb/tests/oversample/ (stored 0%)
#   adding: content/stb/tests/oversample/oversample.exe (deflated 26%)
#   adding: content/stb/tests/oversample/oversample.dsw (deflated 61%)
#   adding: content/stb/tests/oversample/stb_wingraph.h (deflated 73%)
#   adding: content/stb/tests/oversample/oversample.dsp (deflated 72%)
#   adding: content/stb/tests/oversample/README.md (deflated 56%)
#   adding: content/stb/tests/oversample/main.c (deflated 67%)
#   adding: content/stb/tests/c_lexer_test.c (deflated 65%)
#   adding: content/stb/tests/test_ds_cpp.cpp (deflated 83%)
#   adding: content/stb/tests/stb_static.c (deflated 56%)
#   adding: content/stb/tests/stb.c (deflated 64%)
#   adding: content/stb/tests/test_image_write.c (deflated 25%)
#   adding: content/stb/tests/pg_test/ (stored 0%)
#   adding: content/stb/tests/pg_test/pg_test.c (deflated 60%)
#   adding: content/stb/tests/stblib_test.c (deflated 35%)
#   adding: content/stb/tests/test_ds.c (deflated 85%)
#   adding: content/stb/tests/stb_cpp.dsp (deflated 75%)
#   adding: content/stb/tests/resample_test.cpp (deflated 82%)
#   adding: content/stb/tests/pbm/ (stored 0%)
#   adding: content/stb/tests/pbm/cdun2c08.ppm (deflated 81%)
#   adding: content/stb/tests/pbm/comment.pgm (deflated 88%)
#   adding: content/stb/tests/pbm/basi0g16.pgm (deflated 72%)
#   adding: content/stb/tests/pbm/basi2c16.ppm (deflated 59%)
#   adding: content/stb/tests/pbm/ctfn0g04.pgm (deflated 92%)
#   adding: content/stb/tests/pbm/cdfn2c08.ppm (deflated 58%)
#   adding: content/stb/tests/ossfuzz.sh (deflated 63%)
#   adding: content/stb/tests/test_c_compilation.c (deflated 60%)
#   adding: content/stb/.git/ (stored 0%)
#   adding: content/stb/.git/description (deflated 14%)
#   adding: content/stb/.git/packed-refs (deflated 26%)
#   adding: content/stb/.git/refs/ (stored 0%)
#   adding: content/stb/.git/refs/heads/ (stored 0%)
#   adding: content/stb/.git/refs/heads/master (stored 0%)
#   adding: content/stb/.git/refs/remotes/ (stored 0%)
#   adding: content/stb/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/stb/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/stb/.git/refs/tags/ (stored 0%)
#   adding: content/stb/.git/index (deflated 64%)
#   adding: content/stb/.git/branches/ (stored 0%)
#   adding: content/stb/.git/config (deflated 34%)
#   adding: content/stb/.git/logs/ (stored 0%)
#   adding: content/stb/.git/logs/refs/ (stored 0%)
#   adding: content/stb/.git/logs/refs/heads/ (stored 0%)
#   adding: content/stb/.git/logs/refs/heads/master (deflated 28%)
#   adding: content/stb/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/stb/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/stb/.git/logs/refs/remotes/origin/HEAD (deflated 28%)
#   adding: content/stb/.git/logs/HEAD (deflated 28%)
#   adding: content/stb/.git/hooks/ (stored 0%)
#   adding: content/stb/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/stb/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/stb/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/stb/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/stb/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/stb/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/stb/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/stb/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/stb/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/stb/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/stb/.git/hooks/update.sample (deflated 68%)
#   adding: content/stb/.git/HEAD (stored 0%)
#   adding: content/stb/.git/objects/ (stored 0%)
#   adding: content/stb/.git/objects/pack/ (stored 0%)
#   adding: content/stb/.git/objects/pack/pack-64335c935a0855f9b2a6582f84576729ee3dff13.pack (deflated 2%)
#   adding: content/stb/.git/objects/pack/pack-64335c935a0855f9b2a6582f84576729ee3dff13.idx (deflated 2%)
#   adding: content/stb/.git/objects/info/ (stored 0%)
#   adding: content/stb/.git/info/ (stored 0%)
#   adding: content/stb/.git/info/exclude (deflated 28%)
#   adding: content/stb/stb_image.h (deflated 75%)
#   adding: content/stb/data/ (stored 0%)
#   adding: content/stb/data/easy_font_raw.png (stored 0%)
#   adding: content/stb/data/map_03.png (deflated 6%)
#   adding: content/stb/data/atari_8bit_font_revised.png (stored 0%)
#   adding: content/stb/data/map_01.png (stored 0%)
#   adding: content/stb/data/map_02.png (deflated 44%)
#   adding: content/stb/data/herringbone/ (stored 0%)
#   adding: content/stb/data/herringbone/template_limited_connectivity.png (deflated 1%)
#   adding: content/stb/data/herringbone/template_ref2_corner_caves.png (deflated 0%)
#   adding: content/stb/data/herringbone/template_horizontal_corridors_v2.png (stored 0%)
#   adding: content/stb/data/herringbone/template_square_rooms_with_random_rects.png (stored 0%)
#   adding: content/stb/data/herringbone/template_simple_caves_2_wide.png (deflated 0%)
#   adding: content/stb/data/herringbone/template_open_areas.png (deflated 1%)
#   adding: content/stb/data/herringbone/template_corner_caves.png (deflated 0%)
#   adding: content/stb/data/herringbone/template_caves_limit_connectivity.png (stored 0%)
#   adding: content/stb/data/herringbone/template_maze_2_wide.png (deflated 4%)
#   adding: content/stb/data/herringbone/template_round_rooms_diagonal_corridors.png (stored 0%)
#   adding: content/stb/data/herringbone/template_rooms_and_corridors.png (stored 0%)
#   adding: content/stb/data/herringbone/template_sean_dungeon.png (stored 0%)
#   adding: content/stb/data/herringbone/template_horizontal_corridors_v3.png (stored 0%)
#   adding: content/stb/data/herringbone/template_maze_plus_2_wide.png (deflated 3%)
#   adding: content/stb/data/herringbone/template_limit_connectivity_fat.png (deflated 0%)
#   adding: content/stb/data/herringbone/template_caves_tiny_corridors.png (stored 0%)
#   adding: content/stb/data/herringbone/template_rooms_limit_connectivity.png (deflated 0%)
#   adding: content/stb/data/herringbone/template_horizontal_corridors_v1.png (stored 0%)
#   adding: content/stb/data/herringbone/template_rooms_and_corridors_2_wide_diagonal_bias.png (stored 0%)
#   adding: content/stb/data/herringbone/license.txt (deflated 32%)
#   adding: content/stb/stb_connected_components.h (deflated 77%)
#   adding: content/stb/LICENSE (deflated 57%)
#   adding: content/stb/stb_image_write.h (deflated 72%)
#   adding: content/stb/stb_perlin.h (deflated 74%)
#   adding: content/convImg/ (stored 0%)
#   adding: content/convImg/con_5.png (deflated 2%)
#   adding: content/convImg/con_6.png (deflated 5%)
#   adding: content/convImg/con_7.png (deflated 3%)
#   adding: content/convImg/con_9.png (deflated 3%)
#   adding: content/convImg/con_3.png (deflated 3%)
#   adding: content/convImg/con_8.png (deflated 4%)
#   adding: content/convImg/con_1.png (deflated 5%)
#   adding: content/convImg/con_2.png (deflated 4%)
#   adding: content/convImg/con_0.png (deflated 3%)
#   adding: content/convImg/con_4.png (deflated 4%)
#   adding: content/stb_image.h (deflated 75%)
#   adding: content/stb_image_write.h (deflated 72%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
